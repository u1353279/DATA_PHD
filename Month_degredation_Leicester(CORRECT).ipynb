# %% [markdown]
# <a href="https://colab.research.google.com/github/u1353279/DATA_PHD/blob/main/Month_degredation_Leicester(CORRECT).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparing Seasonal degredation of 3 PV systems based on 3 month intervals located in Leicester

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# settings
plt.style.use('seaborn-white')
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# # Leicester PV-01 JAN-MAR

# %%
Leicester_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

df = Leicester_1[(Leicester_1['Unnamed: 1']>0) & (Leicester_1['Unnamed: 1']<4)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JAN-MARCH:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.68
# Lower boundary degredation value -0.39625992721111614
# Upper boundary degredation value -0.9684459551418335

# %% [markdown]
# # Leicester PV-02 JAN-MAR

# %%
Leicester_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

df = Leicester_2[(Leicester_2['Unnamed: 1']>0) & (Leicester_2['Unnamed: 1']<4)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JAN-MARCH:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.82
# Lower boundary degredation value -0.5645309575720918
# Upper boundary degredation value -1.0825278659573287

# %% [markdown]
# # Leicester PV-03 JAN-MAR

# %%
Leicester_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

df = Leicester_3[(Leicester_3['Unnamed: 1']>0) & (Leicester_3['Unnamed: 1']<4)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Leicester PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JAN-MARCH:Degradation Rate for Bedford PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.75
# Lower boundary degredation value -0.5914165090547585
# Upper boundary degredation value -0.9144658438864247

# %% [markdown]
# ## Avg degredation for Leicester between JAN-March is -0.75%

# %% [markdown]
# # Leicester PV-01 APR-JUN

# %%
Leicester_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

df = Leicester_1[(Leicester_1['Unnamed: 1']>3) & (Leicester_1['Unnamed: 1']<7)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("APR-JUN:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.8
# Lower boundary degredation value -0.5749669675595573
# Upper boundary degredation value -1.025033032440457

# %% [markdown]
# # Leicester PV-02 APR-JUN

# %%
Leicester_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

df = Leicester_2[(Leicester_2['Unnamed: 1']>3) & (Leicester_2['Unnamed: 1']<7)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("APR-JUN:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.83
# Lower boundary degredation value -0.43391323537134374
# Upper boundary degredation value -1.224910294040435

# %% [markdown]
# # Leicester PV-03 APR-JUN

# %%
Leicester_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

df = Leicester_3[(Leicester_3['Unnamed: 1']>3) & (Leicester_3['Unnamed: 1']<7)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Leicester PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("APR-JUN:Degradation Rate for Leicester PV-03")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.55
# Lower boundary degredation value -0.21372531656943802
# Upper boundary degredation value -0.8892158599011584

# %% [markdown]
# ## Avg degredation for Leicester between Apr-Jun is -0.73%

# %% [markdown]
# # Leicester PV-01 JUL-SEPT

# %%
Leicester_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

df = Leicester_1[(Leicester_1['Unnamed: 1']>6) & (Leicester_1['Unnamed: 1']<10)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUL-SEPT:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.64
# Lower boundary degredation value -0.43756830498010263
# Upper boundary degredation value -0.8477258126669622

# %% [markdown]
# # Leicester PV-02 JUL-SEPT

# %%
Leicester_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

df = Leicester_2[(Leicester_2['Unnamed: 1']>6) & (Leicester_2['Unnamed: 1']<10)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUL-SEPT:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.71
# Lower boundary degredation value -0.2528128109318315
# Upper boundary degredation value -1.1648342478917035

# %% [markdown]
# # Leicester PV-03 JUL-SEPT

# %%
Leicester_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

df = Leicester_3[(Leicester_3['Unnamed: 1']>6) & (Leicester_3['Unnamed: 1']<10)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUL-SEPT:Degradation Rate for Leicester PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.47
# Lower boundary degredation value -0.0692234855470027
# Upper boundary degredation value -0.8631294556294753

# %% [markdown]
# ## Avg degredation for Leicester between Jul-Sept is -0.60%

# %% [markdown]
# # Leicester PV-01 OCT-DEC

# %%
Leicester_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

df = Leicester_1[(Leicester_1['Unnamed: 1']>9) & (Leicester_1['Unnamed: 1']<13)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("OCT-DEC:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -1.14
# Lower boundary degredation value -0.5326715096826332
# Upper boundary degredation value -1.737916725611495

# %% [markdown]
# # Leicester PV-02 OCT-DEC

# %%
Leicester_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

df = Leicester_2[(Leicester_2['Unnamed: 1']>9) & (Leicester_2['Unnamed: 1']<13)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("OCT-DEC:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.12
# Lower boundary degredation value 0.3229022250772613
# Upper boundary degredation value -0.5670198721361013

# %% [markdown]
# # Leicester PV-03 OCT-DEC

# %%
Leicester_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

df = Leicester_3[(Leicester_3['Unnamed: 1']>9) & (Leicester_3['Unnamed: 1']<13)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("OCT-DEC:Degradation Rate for Leicester PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.43
# Lower boundary degredation value 0.07030212780847458
# Upper boundary degredation value -0.9350080101614261

# %% [markdown]
# ## Avg degredation for Leicester between Oct-Dec is -0.56%

# %%
# https://www.carboncommentary.com/blog/2019/12/6/how-fast-do-solar-panels-degrade-evidence-from-a-single-house-over-15-years
