# %% [markdown]
# <a href="https://colab.research.google.com/github/u1353279/DATA_PHD/blob/main/Correct_Leicester.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparing Seasonal degredation of 3 PV systems based on 3 month intervals located in Leicester

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# settings
plt.style.use('seaborn-white')
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# # Leicester PV-01 MAR-MAY

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>2) & (bedford_1['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("MAR-May:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.28
# Lower boundary degredation value 0.3571315197838664
# Upper boundary degredation value -0.9205990120439411

# %% [markdown]
# # Leicester PV-02 MAR-MAY

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>2) & (bedford_2['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("MAR-MAY:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.81
# Lower boundary degredation value -0.013076440908204645
# Upper boundary degredation value -1.6030226302992365

# %% [markdown]
# # Leicester PV-03 MAR-MAY

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>2) & (bedford_3['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("MAR-MAY:Degradation Rate for Leicester PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.74
# Lower boundary degredation value -0.039450144808054366
# Upper boundary degredation value -1.4342340657182766

# %% [markdown]
# ## Avg degredation for Leicester between MAR-MAY is -1.3%

# %% [markdown]
# # Leicester PV-01 JUN-AUG

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>5) & (bedford_1['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("JUN-AUG:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -1.16
# Lower boundary degredation value -0.31881754545535596
# Upper boundary degredation value -2.003163878693267

# %% [markdown]
# # Leicester PV-02 JUN-AUG

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>5) & (bedford_2['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("JUN-AUG:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.93
# Lower boundary degredation value -0.25288916981403
# Upper boundary degredation value -1.6046959695048741

# %% [markdown]
# # Leicester PV-03 JUN-AUG

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>5) & (bedford_3['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("JUN-AUG:Degradation Rate for Leicester PV-03")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.33
# Lower boundary degredation value 0.22183603443006888
# Upper boundary degredation value -0.8781827836560916

# %% [markdown]
# ## Avg degredation for Bedford between JUN-AUG is -0.81%

# %% [markdown]
# # Bedford PV-01 SEPT-NOV

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>8) & (bedford_1['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("SEPT-NOV:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.87
# Lower boundary degredation value -0.047167093260923665
# Upper boundary degredation value -1.692770987234454

# %% [markdown]
# # Leicester PV-02 SEPT-NOV

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>8) & (bedford_2['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("SEPT-NOV:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.53
# Lower boundary degredation value 0.3378204817512418
# Upper boundary degredation value -1.402835961627424

# %% [markdown]
# # Leicester PV-03 SEPT-NOV

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>8) & (bedford_3['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("SEPT-NOV:Degradation Rate for Bedford PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.72
# Lower boundary degredation value 0.03377545009186422
# Upper boundary degredation value -1.4826918587606115

# %% [markdown]
# ## Avg degredation for Leicester between SEPT-NOV is -0.71%

# %% [markdown]
# # Leicester PV-01 DEC-FEB

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

data = bedford_1[(bedford_1['Unnamed: 1']<3) | (bedford_1['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("DEC-FEB:Degradation Rate for Bedford PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.85
# Lower boundary degredation value -0.3690631324246275
# Upper boundary degredation value -1.333723245284367

# %% [markdown]
# # Leicester PV-02 DEC-FEB

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

data = bedford_2[(bedford_1['Unnamed: 1']<3) | (bedford_2['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("OCT-DEC:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.4
# Lower boundary degredation value 0.26108037400348516
# Upper boundary degredation value -1.0660339343750151

# %% [markdown]
# # Leicester PV-03 DEC-FEB

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

data = bedford_3[(bedford_1['Unnamed: 1']<3) | (bedford_3['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 1)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 18)
plt.title("OCT-DEC:Degradation Rate for Leicester PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.3
# Lower boundary degredation value 0.37248246394828305
# Upper boundary degredation value -0.9731016589947359

# %% [markdown]
# ## Avg degredation for Bedford between DEC-FEB is -0.52%

# %%
# https://www.carboncommentary.com/blog/2019/12/6/how-fast-do-solar-panels-degrade-evidence-from-a-single-house-over-15-years
