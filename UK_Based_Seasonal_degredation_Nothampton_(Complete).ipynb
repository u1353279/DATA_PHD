# %% [markdown]
# <a href="https://colab.research.google.com/github/u1353279/DATA_PHD/blob/main/UK_Based_Seasonal_degredation_Nothampton_(Complete).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparing Seasonal degredation of 3 PV systems based on 3 month intervals located in Northampton

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# settings
plt.style.use('seaborn-white')
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# # Northampton PV-01 MAR-MAY

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>2) & (bedford_1['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("MAR-May:Degradation Rate for Northampton PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value 0.11
# Lower boundary degredation value 0.40976738316942507
# Upper boundary degredation value -0.18917914787531626

# %% [markdown]
# # Northampton PV-02 MAR-MAY

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>2) & (bedford_2['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("MAR-MAY:Degradation Rate for Northampton PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.71
# Lower boundary degredation value -0.3206527914454317
# Upper boundary degredation value -1.1058177967898706

# %% [markdown]
# # Northampton PV-03 MAR-MAY

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>2) & (bedford_3['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("MAR-MAY:Degradation Rate for Northampton PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.53
# Lower boundary degredation value -0.30045854216904894
# Upper boundary degredation value -0.7642473401838977

# %% [markdown]
# ## Avg degredation for Northampton between MAR-MAY is -0.45%

# %% [markdown]
# # Northampton PV-01 JUN-AUG

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>5) & (bedford_1['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUN-AUG:Degradation Rate for Northampton PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.58
# Lower boundary degredation value -0.0886510149390611
# Upper boundary degredation value -1.0731136909433037

# %% [markdown]
# # Northampton PV-02 JUN-AUG

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>5) & (bedford_2['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUN-AUG:Degradation Rate for Northampton PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.74
# Lower boundary degredation value -0.5560509940564279
# Upper boundary degredation value -0.9233607706494665

# %% [markdown]
# # Northampton PV-03 JUN-AUG

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>5) & (bedford_3['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUN-AUG:Degradation Rate for Northampton PV-03")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.72
# Lower boundary degredation value -0.4831558141531235
# Upper boundary degredation value -0.9550794799645359

# %% [markdown]
# ## Avg degredation for Northampton between JUN-AUG is -0.68%

# %% [markdown]
# # Northampton PV-01 SEPT-NOV

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>8) & (bedford_1['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("SEPT-NOV:Degradation Rate for Northampton PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.79
# Lower boundary degredation value -0.48427667291590626
# Upper boundary degredation value -1.1039586212017551

# %% [markdown]
# # Northampton PV-02 SEPT-NOV

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>8) & (bedford_2['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("SEPT-NOV:Degradation Rate for Northampton PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.42
# Lower boundary degredation value -0.1029074506968573
# Upper boundary degredation value -0.729445490479621

# %% [markdown]
# # Northampton PV-03 SEPT-NOV

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>8) & (bedford_3['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("SEPT-NOV:Degradation Rate for Northampton PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.56
# Lower boundary degredation value -0.10651818810993424
# Upper boundary degredation value -1.017011223654785

# %% [markdown]
# ## Avg degredation for Northampton between SEPT-NOV is -0.59%

# %% [markdown]
# # Northampton PV-01 DEC-FEB

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton1.csv')

data = bedford_1[(bedford_1['Unnamed: 1']<3) | (bedford_1['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("DEC-FEB:Degradation Rate for Northampton PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.16
# Lower boundary degredation value 0.281206058206796
# Upper boundary degredation value -0.5959119405597467

# %% [markdown]
# # Northampton PV-02 DEC-FEB

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton2.csv')

data = bedford_2[(bedford_1['Unnamed: 1']<3) | (bedford_2['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("OCT-DEC:Degradation Rate for Northampton PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.64
# Lower boundary degredation value -0.48133757224984164
# Upper boundary degredation value -0.7892506630442861

# %% [markdown]
# # Northampton PV-03 DEC-FEB

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Northampton3.csv')

data = bedford_3[(bedford_1['Unnamed: 1']<3) | (bedford_3['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("OCT-DEC:Degradation Rate for Northampton PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.68
# Lower boundary degredation value -0.5245807468298223
# Upper boundary degredation value -0.834242782581955

# %% [markdown]
# ## Avg degredation for Northampton between DEC-FEB is -0.49%

# %%
# https://www.carboncommentary.com/blog/2019/12/6/how-fast-do-solar-panels-degrade-evidence-from-a-single-house-over-15-years
