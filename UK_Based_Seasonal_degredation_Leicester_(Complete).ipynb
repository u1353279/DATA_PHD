# %% [markdown]
# <a href="https://colab.research.google.com/github/u1353279/DATA_PHD/blob/main/UK_Based_Seasonal_degredation_Leicester_(Complete).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparing Seasonal degredation of 3 PV systems based on 3 month intervals located in Leicester

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# settings
plt.style.use('seaborn-white')
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# # Leicester PV-01 MAR-MAY

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>2) & (bedford_1['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("MAR-May:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.45
# Lower boundary degredation value -0.2511987309633945
# Upper boundary degredation value -0.6576247984483776

# %% [markdown]
# # Leicester PV-02 MAR-MAY

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>2) & (bedford_2['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("MAR-MAY:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -1.05
# Lower boundary degredation value -0.6030860021007582
# Upper boundary degredation value -1.499855174369848

# %% [markdown]
# # Leicester PV-03 MAR-MAY

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>2) & (bedford_3['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("MAR-MAY:Degradation Rate for Leicester PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.79
# Lower boundary degredation value -0.4851244583585129
# Upper boundary degredation value -1.0972284828179732

# %% [markdown]
# ## Avg degredation for Leicester between MAR-MAY is -0.76%

# %% [markdown]
# # Leicester PV-01 JUN-AUG

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>5) & (bedford_1['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUN-AUG:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -1.16
# Lower boundary degredation value -0.9749754375435661
# Upper boundary degredation value -1.3485539742211516

# %% [markdown]
# # Leicester PV-02 JUN-AUG

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>5) & (bedford_2['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUN-AUG:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.98
# Lower boundary degredation value -0.5297507623839327
# Upper boundary degredation value -1.4378962964396058

# %% [markdown]
# # Leicester PV-03 JUN-AUG

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>5) & (bedford_3['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUN-AUG:Degradation Rate for Leicester PV-03")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.31
# Lower boundary degredation value -0.03143697998719289
# Upper boundary degredation value -0.5803277258951659

# %% [markdown]
# ## Avg degredation for Bedford between JUN-AUG is -0.81%

# %% [markdown]
# # Bedford PV-01 SEPT-NOV

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>8) & (bedford_1['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("SEPT-NOV:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.56
# Lower boundary degredation value -0.11534543533949154
# Upper boundary degredation value -1.0111251528958118

# %% [markdown]
# # Leicester PV-02 SEPT-NOV

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>8) & (bedford_2['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("SEPT-NOV:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.15
# Lower boundary degredation value 0.12936943427593894
# Upper boundary degredation value -0.43819296368771454

# %% [markdown]
# # Leicester PV-03 SEPT-NOV

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>8) & (bedford_3['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("SEPT-NOV:Degradation Rate for Bedford PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.48
# Lower boundary degredation value -0.05718335726161694
# Upper boundary degredation value -0.9104637015619317

# %% [markdown]
# ## Avg degredation for Leicester between SEPT-NOV is -0.40%

# %% [markdown]
# # Leicester PV-01 DEC-FEB

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester1.csv')

data = bedford_1[(bedford_1['Unnamed: 1']<3) | (bedford_1['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("DEC-FEB:Degradation Rate for Bedford PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.79
# Lower boundary degredation value -0.5880400859514867
# Upper boundary degredation value -0.9972540316955798

# %% [markdown]
# # Leicester PV-02 DEC-FEB

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester2.csv')

data = bedford_2[(bedford_1['Unnamed: 1']<3) | (bedford_2['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("OCT-DEC:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.42
# Lower boundary degredation value -0.024798568395246606
# Upper boundary degredation value -0.8104955492518213

# %% [markdown]
# # Leicester PV-03 DEC-FEB

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Leicester3.csv')

data = bedford_3[(bedford_1['Unnamed: 1']<3) | (bedford_3['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("OCT-DEC:Degradation Rate for Leicester PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.48
# Lower boundary degredation value -0.1867038558995741
# Upper boundary degredation value -0.7809432029239666

# %% [markdown]
# ## Avg degredation for Bedford between DEC-FEB is -0.56%

# %%
# https://www.carboncommentary.com/blog/2019/12/6/how-fast-do-solar-panels-degrade-evidence-from-a-single-house-over-15-years
