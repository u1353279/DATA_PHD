# %% [markdown]
# <a href="https://colab.research.google.com/github/u1353279/DATA_PHD/blob/main/UK_Based_Seasonal_degredation_Milton_(Complete).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Comparing Seasonal degredation of 3 PV systems based on 3 month intervals located in Milton

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
from matplotlib import pyplot as plt
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# settings
plt.style.use('seaborn-white')
plt.rcParams["figure.figsize"] = (8, 5)

# %% [markdown]
# # Milton PV-01 MAR-MAY

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>2) & (bedford_1['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("MAR-May:Degradation Rate for Milton PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.63
# Lower boundary degredation value -0.15702054007354238
# Upper boundary degredation value -1.1076853422794115

# %% [markdown]
# # Milton PV-02 MAR-MAY

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>2) & (bedford_2['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("MAR-MAY:Degradation Rate for Milton PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.53
# Lower boundary degredation value -0.15145041547563304
# Upper boundary degredation value -0.9044319374655543

# %% [markdown]
# # Milton PV-03 MAR-MAY

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>2) & (bedford_3['Unnamed: 1']<6)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("MAR-MAY:Degradation Rate for Milton PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.55
# Lower boundary degredation value -0.2192016723114682
# Upper boundary degredation value -0.8719747982767699

# %% [markdown]
# ## Avg degredation for Milton between MAR-MAY is -0.57%

# %% [markdown]
# # Milton PV-01 JUN-AUG

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>5) & (bedford_1['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUN-AUG:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.98
# Lower boundary degredation value -0.6750500559302473
# Upper boundary degredation value -1.2837734734815305

# %% [markdown]
# # Milton PV-02 JUN-AUG

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>5) & (bedford_2['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUN-AUG:Degradation Rate for Milton PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.76
# Lower boundary degredation value -0.2683950293938043
# Upper boundary degredation value -1.2580755588415018

# %% [markdown]
# # Milton PV-03 JUN-AUG

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>5) & (bedford_3['Unnamed: 1']<9)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("JUN-AUG:Degradation Rate for Milton PV-03")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -1.3
# Lower boundary degredation value -0.8941778047466962
# Upper boundary degredation value -1.696998665841546

# %% [markdown]
# ## Avg degredation for Milton between JUN-AUG is -1.01%

# %% [markdown]
# # Milton PV-01 SEPT-NOV

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton1.csv')

df = bedford_1[(bedford_1['Unnamed: 1']>8) & (bedford_1['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("SEPT-NOV:Degradation Rate for Leicester PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.89
# Lower boundary degredation value -0.4164034650862738
# Upper boundary degredation value -1.363008299619617

# %% [markdown]
# # Milton PV-02 SEPT-NOV

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton2.csv')

df = bedford_2[(bedford_2['Unnamed: 1']>8) & (bedford_2['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("SEPT-NOV:Degradation Rate for Leicester PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value -0.16
# Lower boundary degredation value 0.40369039867423395
# Upper boundary degredation value -0.727219810438948

# %% [markdown]
# # Milton PV-03 SEPT-NOV

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton3.csv')

df = bedford_3[(bedford_3['Unnamed: 1']>8) & (bedford_3['Unnamed: 1']<12)]

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("SEPT-NOV:Degradation Rate for Milton PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# Absolute degredation value 0.0
# Lower boundary degredation value 0.37572756964339715
# Upper boundary degredation value -0.3727863931728249

# %% [markdown]
# ## Avg degredation for Milton between SEPT-NOV is -0.35%

# %% [markdown]
# # Milton PV-01 DEC-FEB

# %%
bedford_1 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton1.csv')

data = bedford_1[(bedford_1['Unnamed: 1']<3) | (bedford_1['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("DEC-FEB:Degradation Rate for Milton PV-1")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -1.11
# Lower boundary degredation value -0.7329168053730275
# Upper boundary degredation value -1.478847900509335

# %% [markdown]
# # Milton PV-02 DEC-FEB

# %%
bedford_2 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton2.csv')

data = bedford_2[(bedford_1['Unnamed: 1']<3) | (bedford_2['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("OCT-DEC:Degradation Rate for Milton PV-2")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.51
# Lower boundary degredation value -0.08233477783720908
# Upper boundary degredation value -0.9323711045157366

# %% [markdown]
# # Milton PV-03 DEC-FEB

# %%
bedford_3 = pd.read_csv('/content/drive/MyDrive/PHD/Data/Milton3.csv')

data = bedford_3[(bedford_1['Unnamed: 1']<3) | (bedford_3['Unnamed: 1']==12)]

data.replace(12, 3,inplace=True)

df=data

#df['PR'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Monthly PR 2015-2020')

#fig, axs = plt.subplots()
#axs.plot(df.index, df.PR, 'o-', alpha = 0.5,color='g')
#axs.set_ylabel('PR (%)');
#axs.set_xlabel('Month')

resolution = 3
s=sm.tsa.seasonal_decompose(df.PR, model = 'multiplicative', freq = 3)
#s.plot()

trend_df = pd.DataFrame(list(s.trend), columns = ['Trend'])
trend_df.insert(loc=0, column = 'Month', value=np.arange(len(trend_df)))
trend_df=trend_df[np.isfinite(trend_df['Trend'])]
y = trend_df.Trend
x = trend_df.Month
x, y = np.array(x), np.array(y)

x = sm.add_constant(x)

#trend_df['Trend'].plot()
#plt.xlabel('Month')
#plt.ylabel('PR')
#plt.title('Decomposed Trend for Bedford PV-2 JAN-APR')

model = sm.OLS(y,x)
results = model.fit()
#results.summary()

#confidence level 95%
intercept, slope = results.params
CI_abs = resolution*results.conf_int(alpha = 0.05)[1]
CIL_abs = CI_abs[1]
CIH_abs = CI_abs[0]
round(CIL_abs,2),round(CIH_abs,2)

DR_abs = round(resolution*slope, 2)


sns.regplot(y = trend_df['Trend'], x = trend_df['Month'], data = df, color='g')
plt.ylabel("PR(%)")
plt.xlabel("Month")
plt.ylim(65,100)
plt.xlim(0, 17)
plt.title("OCT-DEC:Degradation Rate for Milton PV-3")
plt.grid(True)
plt.show()

print('Absolute degredation value', DR_abs)
print('Lower boundary degredation value', CIL_abs)
print('Upper boundary degredation value', CIH_abs)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:4389: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,
# Absolute degredation value -0.53
# Lower boundary degredation value -0.19929901501289604
# Upper boundary degredation value -0.8536421614577032

# %% [markdown]
# ## Avg degredation for Milton between DEC-FEB is -0.72%

# %%
# https://www.carboncommentary.com/blog/2019/12/6/how-fast-do-solar-panels-degrade-evidence-from-a-single-house-over-15-years
